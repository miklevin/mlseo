# %%
# hide

# default_exp pip_upgrades

# %load_ext lab_black
from nbdev.showdoc import *

# %% [markdown]
# # Upgrade Pip Installs
#
# Versions will always trip you up. Generally, you want to be on the latest version of everything except where you have to hold-back to keep things from breaking.
#
# The next two !commands list all all your pip components and the ones needing upgrade, just for your information. The next 2 cells do not change anything on your system.

# %%
# hide
# List all packages
# This will work without admin rights


# %pip list
# Out:
# Package                       Version
# ----------------------------- -----------
# anyio                         3.6.1
# appdirs                       1.4.4
# argon2-cffi                   21.3.0
# argon2-cffi-bindings          21.2.0
# art                           5.6
# asttokens                     2.0.5
# attrs                         21.4.0
# Babel                         2.10.1
# backcall                      0.2.0
# backports.functools-lru-cache 1.6.4
# beautifulsoup4                4.11.1
# black                         22.3.0
# bleach                        5.0.0
# brotlipy                      0.7.0
# cachetools                    5.1.0
# certifi                       2021.10.8
# cffi                          1.15.0
# charset-normalizer            2.0.12
# click                         8.1.3
# colorama                      0.4.4
# commonmark                    0.9.1
# conda                         4.12.0
# conda-package-handling        1.8.1
# cryptography                  37.0.2
# cycler                        0.11.0
# debugpy                       1.6.0
# decorator                     5.1.1
# defusedxml                    0.7.1
# dumbquotes                    0.0.3
# entrypoints                   0.4
# et-xmlfile                    1.1.0
# executing                     0.8.3
# fastcore                      1.4.3
# fastjsonschema                2.15.3
# fastrelease                   0.1.16
# filelock                      3.7.0
# flit_core                     3.7.1
# fonttools                     4.33.3
# ghapi                         0.1.20
# google-analytics-admin        0.8.0
# google-api-core               2.7.3
# google-api-python-client      2.48.0
# google-auth                   2.6.6
# google-auth-httplib2          0.1.0
# google-auth-oauthlib          0.5.1
# googleapis-common-protos      1.56.1
# grpcio                        1.46.1
# grpcio-status                 1.46.1
# h11                           0.12.0
# httpcore                      0.15.0
# httplib2                      0.20.4
# httpx                         0.22.0
# idna                          3.3
# importlib-metadata            4.11.3
# importlib-resources           5.7.1
# install                       1.3.5
# ipykernel                     6.13.0
# ipympl                        0.9.1
# ipython                       8.3.0
# ipython-genutils              0.2.0
# ipywidgets                    7.7.0
# jedi                          0.18.1
# jellyfish                     0.9.0
# Jinja2                        3.0.3
# joblib                        1.1.0
# json5                         0.9.8
# jsonschema                    4.5.1
# jupyter                       1.0.0
# jupyter-client                7.3.1
# jupyter-console               6.4.3
# jupyter-core                  4.10.0
# jupyter-server                1.17.0
# jupyterlab                    3.4.2
# jupyterlab-pygments           0.2.2
# jupyterlab-server             2.13.0
# jupyterlab-widgets            1.1.0
# kiwisolver                    1.4.2
# lxml                          4.8.0
# MarkupSafe                    2.1.1
# matplotlib                    3.5.2
# matplotlib-inline             0.1.3
# menuinst                      1.4.18
# mistune                       0.8.4
# mlseo                         0.0.22
# munkres                       1.1.4
# mypy-extensions               0.4.3
# nb-black                      1.0.7
# nbclassic                     0.3.7
# nbclient                      0.6.3
# nbconvert                     6.5.0
# nbdev                         1.2.8
# nbformat                      5.4.0
# nest-asyncio                  1.5.5
# networkx                      2.8
# nltk                          3.7
# notebook                      6.4.11
# notebook-shim                 0.1.0
# numpy                         1.22.3
# oauthlib                      3.2.0
# ohawf                         0.0.21
# openpyxl                      3.0.9
# packaging                     21.3
# pandas                        1.4.2
# pandocfilters                 1.5.0
# parso                         0.8.3
# pathspec                      0.9.0
# pickleshare                   0.7.5
# Pillow                        9.1.1
# pip                           22.1
# pipdeptree                    2.2.1
# platformdirs                  2.5.2
# prometheus-client             0.14.1
# prompt-toolkit                3.0.29
# proto-plus                    1.20.3
# protobuf                      3.20.1
# psutil                        5.9.0
# pure-eval                     0.2.2
# pyasn1                        0.4.8
# pyasn1-modules                0.2.8
# pycosat                       0.6.3
# pycparser                     2.21
# pyee                          9.0.4
# Pygments                      2.12.0
# pyOpenSSL                     22.0.0
# pyparsing                     3.0.9
# pyppeteer                     1.0.2
# pyrsistent                    0.18.1
# PySocks                       1.7.1
# python-dateutil               2.8.2
# python-slugify                6.1.2
# pytz                          2022.1
# pywin32                       303
# pywinpty                      2.0.5
# PyYAML                        6.0
# pyzmq                         22.3.0
# qtconsole                     5.3.0
# QtPy                          2.1.0
# regex                         2022.4.24
# requests                      2.27.1
# requests-file                 1.5.1
# requests-oauthlib             1.3.1
# rfc3986                       2.0.0
# rich                          12.4.1
# rsa                           4.8
# ruamel-yaml-conda             0.15.80
# scipy                         1.8.0
# segtok                        1.5.11
# Send2Trash                    1.8.0
# setuptools                    62.3.1
# six                           1.16.0
# sniffio                       1.2.0
# soupsieve                     2.3.2.post1
# sqlitedict                    2.0.0
# stack-data                    0.2.0
# tabulate                      0.8.9
# terminado                     0.15.0
# text-unidecode                1.3
# tinycss2                      1.1.1
# tldextract                    3.3.0
# tomli                         2.0.1
# tornado                       6.1
# tqdm                          4.64.0
# traitlets                     5.2.1.post0
# typer                         0.4.1
# typing_extensions             4.2.0
# unicodedata2                  14.0.0
# uritemplate                   4.1.1
# urllib3                       1.26.9
# wcwidth                       0.2.5
# webencodings                  0.5.1
# websocket-client              1.3.2
# websockets                    10.3
# wheel                         0.37.1
# widgetsnbextension            3.6.0
# win-inet-pton                 1.1.0
# yake                          0.4.8
# zipp                          3.8.0
# Note: you may need to restart the kernel to use updated packages.

# %%
# hide
# List all out-of-date packages
# This will work without admin rights

# %pip list -o
# Out:
# Package                Version   Latest      Type
# ---------------------- --------- ----------- -----
# certifi                2021.10.8 2022.5.18.1 wheel
# google-analytics-admin 0.8.0     0.8.1       wheel
# google-api-core        2.7.3     2.8.0       wheel
# h11                    0.12.0    0.13.0      wheel
# Jinja2                 3.0.3     3.1.2       wheel
# jupyterlab-server      2.13.0    2.14.0      wheel
# mistune                0.8.4     2.0.2       wheel
# networkx               2.8       2.8.1       wheel
# openpyxl               3.0.9     3.0.10      wheel
# proto-plus             1.20.3    1.20.4      wheel
# pywin32                303       304         wheel
# pyzmq                  22.3.0    23.0.0      wheel
# scipy                  1.8.0     1.8.1       wheel
# setuptools             62.3.1    62.3.2      wheel
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Writing a requirements.txt
#
# The cells below writes a "requirements.txt" file onto your machine which will let you instantly go back to all your original versions. It does not perform the upgrades yet. It merely captures all your currently installed versions and locations into a file.

# %%
# export

import subprocess
from os import name

# Windows handles line-returns differently.
lr = "\n"
if name == "nt":
    lr = "\r\n"

# List currenly installed pip packages.
out = subprocess.Popen(
    ["pip", "freeze"],
    stdout=subprocess.PIPE,
    stderr=subprocess.STDOUT,
)
stdout, stderr = out.communicate()

# Write a requirements.txt file as a "before" upgrades.
with open("requirements.txt", "w") as fh:
    decoded_out = stdout.decode("utf8")
    if name == "nt":
        decoded_out.replace("\r\n", "\n")
    fh.write(decoded_out)

print("Done")
# Out:
# Done

# %% [markdown]
# # Performing the upgrades
#
# The cell below performs all the pip upgrades, writing the outputs to a variable you can inspect.

# %%
# export

# Upgrade all pip packages

out = subprocess.Popen(
    ["pip", "list", "-o"], stdout=subprocess.PIPE, stderr=subprocess.STDOUT
)
stdout, stderr = out.communicate()
table = []

for item in stdout.decode("utf8").split(lr):
    table.append(item.split())
table = table[2:-1]
upgrades = [x[0] for x in table]

outputs = []
for item in upgrades:
    out = subprocess.Popen(
        ["pip", "install", "-U", item], stdout=subprocess.PIPE, stderr=subprocess.STDOUT
    )
    stdout, stderr = out.communicate()
    row = (item, stdout, stderr)
    outputs.append(row)
    print(item)
    print()
    print("stdout: ", stdout)
    print()
    print("stderr: ", stderr)
    print()

print("Done")
# Out:
# certifi
#
# stdout:  b"Requirement already satisfied: certifi in c:\\users\\mikle\\appdata\\roaming\\jupyterlab-desktop\\jlab_server\\lib\\site-packages (2021.10.8)\r\nCollecting certifi\r\n  Downloading certifi-2022.5.18.1-py3-none-any.whl (155 kB)\r\n     -------------------------------------- 155.2/155.2 kB 1.9 MB/s eta 0:00:00\r\nInstalling collected packages: certifi\r\n  Attempting uninstall: certifi\r\n    Found existing installation: certifi 2021.10.8\r\n    Uninstalling certifi-2021.10.8:\r\n      Successfully uninstalled certifi-2021.10.8\r\nERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.\r\npyppeteer 1.0.2 requires pyee<9.0.0,>=8.1.0, but you have pyee 9.0.4 which is incompatible.\r\nhttpx 0.22.0 requires httpcore<0.15.0,>=0.14.5, but you have httpcore 0.15.0 which is incompatible.\r\nhttpx 0.22.0 requires rfc3986[idna2008]<2,>=1.3, but you have rfc3986 2.0.0 which is incompatible.\r\nSuccessfully installed certifi-2022.5.18.1\r\n"
#
# stderr:  None
#
# google-analytics-admin
#
# stdout:  b'Requirement already satisfied: google-analytics-admin in c:\\users\\mikle\\appdata\\roaming\\jupyterlab-desktop\\jlab_server\\lib\\site-packages (0.8.0)\r\nCollecting google-analytics-admin\r\n  Downloading google_analytics_admin-0.8.1-py2.py3-none-any.whl (98 kB)\r\n     ---------------------------------------- 99.0/99.0 kB 1.4 MB/s eta 0:00:00\r\nRequirement already satisfied: proto-plus>=1.15.0 in c:\\users\\mikle\\appdata\\roaming\\jupyterlab-desktop\\jlab_server\\lib\\site-packages (from google-analytics-admin) (1.20.3)\r\nRequirement already satisfied: google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5 in c:\\users\\mikle\\appdata\\roaming\\jupyterlab-desktop\\jlab_server\\lib\\site-packages (from google-analytics-admin) (2.7.3)\r\nRequirement already satisfied: google-auth<3.0dev,>=1.25.0 in c:\\users\\mikle\\appdata\\roaming\\jupyterlab-desktop\\jlab_server\\lib\\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-analytics-admin) (2.6.6)\r\nRequirement already satisfied: protobuf>=3.12.0 in c:\\users\\mikle\\appdata\\roaming\\jupyterlab-desktop\\jlab_server\\lib\\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-analytics-admin) (3.20.1)\r\nRequirement already satisfied: requests<3.0.0dev,>=2.18.0 in c:\\users\\mikle\\appdata\\roaming\\jupyterlab-desktop\\jlab_server\\lib\\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-analytics-admin) (2.27.1)\r\nRequirement already satisfied: googleapis-common-protos<2.0dev,>=1.52.0 in c:\\users\\mikle\\appdata\\roaming\\jupyterlab-desktop\\jlab_server\\lib\\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-analytics-admin) (1.56.1)\r\nRequirement already satisfied: grpcio<2.0dev,>=1.33.2 in c:\\users\\mikle\\appdata\\roaming\\jupyterlab-desktop\\jlab_server\\lib\\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-analytics-admin) (1.46.1)\r\nRequirement already satisfied: grpcio-status<2.0dev,>=1.33.2 in c:\\users\\mikle\\appdata\\roaming\\jupyterlab-desktop\\jlab_server\\lib\\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-analytics-admin) (1.46.1)\r\nRequirement already satisfied: rsa<5,>=3.1.4 in c:\\users\\mikle\\appdata\\roaming\\jupyterlab-desktop\\jlab_server\\lib\\site-packages (from google-auth<3.0dev,>=1.25.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-analytics-admin) (4.8)\r\nRequirement already satisfied: cachetools<6.0,>=2.0.0 in c:\\users\\mikle\\appdata\\roaming\\jupyterlab-desktop\\jlab_server\\lib\\site-packages (from google-auth<3.0dev,>=1.25.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-analytics-admin) (5.1.0)\r\nRequirement already satisfied: pyasn1-modules>=0.2.1 in c:\\users\\mikle\\appdata\\roaming\\jupyterlab-desktop\\jlab_server\\lib\\site-packages (from google-auth<3.0dev,>=1.25.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-analytics-admin) (0.2.8)\r\nRequirement already satisfied: six>=1.9.0 in c:\\users\\mikle\\appdata\\roaming\\jupyterlab-desktop\\jlab_server\\lib\\site-packages (from google-auth<3.0dev,>=1.25.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-analytics-admin) (1.16.0)\r\nRequirement already satisfied: certifi>=2017.4.17 in c:\\users\\mikle\\appdata\\roaming\\jupyterlab-desktop\\jlab_server\\lib\\site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-analytics-admin) (2022.5.18.1)\r\nRequirement already satisfied: idna<4,>=2.5 in c:\\users\\mikle\\appdata\\roaming\\jupyterlab-desktop\\jlab_server\\lib\\site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,! ...
#
# stderr:  None
#
# google-api-core
#
# stdout:  b'Requirement already satisfied: google-api-core in c:\\users\\mikle\\appdata\\roaming\\jupyterlab-desktop\\jlab_server\\lib\\site-packages (2.7.3)\r\nCollecting google-api-core\r\n  Downloading google_api_core-2.8.0-py3-none-any.whl (114 kB)\r\n     -------------------------------------- 114.7/114.7 kB 1.7 MB/s eta 0:00:00\r\nRequirement already satisfied: requests<3.0.0dev,>=2.18.0 in c:\\users\\mikle\\appdata\\roaming\\jupyterlab-desktop\\jlab_server\\lib\\site-packages (from google-api-core) (2.27.1)\r\nRequirement already satisfied: protobuf>=3.12.0 in c:\\users\\mikle\\appdata\\roaming\\jupyterlab-desktop\\jlab_server\\lib\\site-packages (from google-api-core) (3.20.1)\r\nRequirement already satisfied: googleapis-common-protos<2.0dev,>=1.52.0 in c:\\users\\mikle\\appdata\\roaming\\jupyterlab-desktop\\jlab_server\\lib\\site-packages (from google-api-core) (1.56.1)\r\nRequirement already satisfied: google-auth<3.0dev,>=1.25.0 in c:\\users\\mikle\\appdata\\roaming\\jupyterlab-desktop\\jlab_server\\lib\\site-packages (from google-api-core) (2.6.6)\r\nRequirement already satisfied: six>=1.9.0 in c:\\users\\mikle\\appdata\\roaming\\jupyterlab-desktop\\jlab_server\\lib\\site-packages (from google-auth<3.0dev,>=1.25.0->google-api-core) (1.16.0)\r\nRequirement already satisfied: pyasn1-modules>=0.2.1 in c:\\users\\mikle\\appdata\\roaming\\jupyterlab-desktop\\jlab_server\\lib\\site-packages (from google-auth<3.0dev,>=1.25.0->google-api-core) (0.2.8)\r\nRequirement already satisfied: cachetools<6.0,>=2.0.0 in c:\\users\\mikle\\appdata\\roaming\\jupyterlab-desktop\\jlab_server\\lib\\site-packages (from google-auth<3.0dev,>=1.25.0->google-api-core) (5.1.0)\r\nRequirement already satisfied: rsa<5,>=3.1.4 in c:\\users\\mikle\\appdata\\roaming\\jupyterlab-desktop\\jlab_server\\lib\\site-packages (from google-auth<3.0dev,>=1.25.0->google-api-core) (4.8)\r\nRequirement already satisfied: charset-normalizer~=2.0.0 in c:\\users\\mikle\\appdata\\roaming\\jupyterlab-desktop\\jlab_server\\lib\\site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core) (2.0.12)\r\nRequirement already satisfied: urllib3<1.27,>=1.21.1 in c:\\users\\mikle\\appdata\\roaming\\jupyterlab-desktop\\jlab_server\\lib\\site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core) (1.26.9)\r\nRequirement already satisfied: certifi>=2017.4.17 in c:\\users\\mikle\\appdata\\roaming\\jupyterlab-desktop\\jlab_server\\lib\\site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core) (2022.5.18.1)\r\nRequirement already satisfied: idna<4,>=2.5 in c:\\users\\mikle\\appdata\\roaming\\jupyterlab-desktop\\jlab_server\\lib\\site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core) (3.3)\r\nRequirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\\users\\mikle\\appdata\\roaming\\jupyterlab-desktop\\jlab_server\\lib\\site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0dev,>=1.25.0->google-api-core) (0.4.8)\r\nInstalling collected packages: google-api-core\r\n  Attempting uninstall: google-api-core\r\n    Found existing installation: google-api-core 2.7.3\r\n    Uninstalling google-api-core-2.7.3:\r\n      Successfully uninstalled google-api-core-2.7.3\r\nSuccessfully installed google-api-core-2.8.0\r\n'
#
# stderr:  None
#
# h11
#
# stdout:  b"Requirement already satisfied: h11 in c:\\users\\mikle\\appdata\\roaming\\jupyterlab-desktop\\jlab_server\\lib\\site-packages (0.12.0)\r\nCollecting h11\r\n  Using cached h11-0.13.0-py3-none-any.whl (58 kB)\r\nInstalling collected packages: h11\r\n  Attempting uninstall: h11\r\n    Found existing installation: h11 0.12.0\r\n    Uninstalling h11-0.12.0:\r\n      Successfully uninstalled h11-0.12.0\r\nERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.\r\nhttpcore 0.15.0 requires h11<0.13,>=0.11, but you have h11 0.13.0 which is incompatible.\r\nSuccessfully installed h11-0.13.0\r\n"
#
# stderr:  None
#
# Jinja2
#
# stdout:  b"Requirement already satisfied: Jinja2 in c:\\users\\mikle\\appdata\\roaming\\jupyterlab-desktop\\jlab_server\\lib\\site-packages (3.0.3)\r\nCollecting Jinja2\r\n  Using cached Jinja2-3.1.2-py3-none-any.whl (133 kB)\r\nRequirement already satisfied: MarkupSafe>=2.0 in c:\\users\\mikle\\appdata\\roaming\\jupyterlab-desktop\\jlab_server\\lib\\site-packages (from Jinja2) (2.1.1)\r\nInstalling collected packages: Jinja2\r\n  Attempting uninstall: Jinja2\r\n    Found existing installation: Jinja2 3.0.3\r\n    Uninstalling Jinja2-3.0.3:\r\n      Successfully uninstalled Jinja2-3.0.3\r\nERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.\r\nnbdev 1.2.8 requires Jinja2<3.1.0, but you have jinja2 3.1.2 which is incompatible.\r\nSuccessfully installed Jinja2-3.1.2\r\n"
#
# stderr:  None
#
# jupyterlab-server
#
# stdout:  b'Requirement already satisfied: jupyterlab-server in c:\\users\\mikle\\appdata\\roaming\\jupyterlab-desktop\\jlab_server\\lib\\site-packages (2.13.0)\r\nCollecting jupyterlab-server\r\n  Downloading jupyterlab_server-2.14.0-py3-none-any.whl (54 kB)\r\n     -------------------------------------- 54.3/54.3 kB 957.4 kB/s eta 0:00:00\r\nRequirement already satisfied: packaging in c:\\users\\mikle\\appdata\\roaming\\jupyterlab-desktop\\jlab_server\\lib\\site-packages (from jupyterlab-server) (21.3)\r\nRequirement already satisfied: jinja2>=3.0.3 in c:\\users\\mikle\\appdata\\roaming\\jupyterlab-desktop\\jlab_server\\lib\\site-packages (from jupyterlab-server) (3.1.2)\r\nRequirement already satisfied: importlib-metadata>=3.6 in c:\\users\\mikle\\appdata\\roaming\\jupyterlab-desktop\\jlab_server\\lib\\site-packages (from jupyterlab-server) (4.11.3)\r\nRequirement already satisfied: jsonschema>=3.0.1 in c:\\users\\mikle\\appdata\\roaming\\jupyterlab-desktop\\jlab_server\\lib\\site-packages (from jupyterlab-server) (4.5.1)\r\nRequirement already satisfied: json5 in c:\\users\\mikle\\appdata\\roaming\\jupyterlab-desktop\\jlab_server\\lib\\site-packages (from jupyterlab-server) (0.9.8)\r\nRequirement already satisfied: babel in c:\\users\\mikle\\appdata\\roaming\\jupyterlab-desktop\\jlab_server\\lib\\site-packages (from jupyterlab-server) (2.10.1)\r\nRequirement already satisfied: jupyter-server<2,>=1.8 in c:\\users\\mikle\\appdata\\roaming\\jupyterlab-desktop\\jlab_server\\lib\\site-packages (from jupyterlab-server) (1.17.0)\r\nRequirement already satisfied: requests in c:\\users\\mikle\\appdata\\roaming\\jupyterlab-desktop\\jlab_server\\lib\\site-packages (from jupyterlab-server) (2.27.1)\r\nRequirement already satisfied: zipp>=0.5 in c:\\users\\mikle\\appdata\\roaming\\jupyterlab-desktop\\jlab_server\\lib\\site-packages (from importlib-metadata>=3.6->jupyterlab-server) (3.8.0)\r\nRequirement already satisfied: MarkupSafe>=2.0 in c:\\users\\mikle\\appdata\\roaming\\jupyterlab-desktop\\jlab_server\\lib\\site-packages (from jinja2>=3.0.3->jupyterlab-server) (2.1.1)\r\nRequirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\\users\\mikle\\appdata\\roaming\\jupyterlab-desktop\\jlab_server\\lib\\site-packages (from jsonschema>=3.0.1->jupyterlab-server) (0.18.1)\r\nRequirement already satisfied: attrs>=17.4.0 in c:\\users\\mikle\\appdata\\roaming\\jupyterlab-desktop\\jlab_server\\lib\\site-packages (from jsonschema>=3.0.1->jupyterlab-server) (21.4.0)\r\nRequirement already satisfied: importlib-resources>=1.4.0 in c:\\users\\mikle\\appdata\\roaming\\jupyterlab-desktop\\jlab_server\\lib\\site-packages (from jsonschema>=3.0.1->jupyterlab-server) (5.7.1)\r\nRequirement already satisfied: argon2-cffi in c:\\users\\mikle\\appdata\\roaming\\jupyterlab-desktop\\jlab_server\\lib\\site-packages (from jupyter-server<2,>=1.8->jupyterlab-server) (21.3.0)\r\nRequirement already satisfied: websocket-client in c:\\users\\mikle\\appdata\\roaming\\jupyterlab-desktop\\jlab_server\\lib\\site-packages (from jupyter-server<2,>=1.8->jupyterlab-server) (1.3.2)\r\nRequirement already satisfied: nbconvert>=6.4.4 in c:\\users\\mikle\\appdata\\roaming\\jupyterlab-desktop\\jlab_server\\lib\\site-packages (from jupyter-server<2,>=1.8->jupyterlab-server) (6.5.0)\r\nRequirement already satisfied: tornado>=6.1.0 in c:\\users\\mikle\\appdata\\roaming\\jupyterlab-desktop\\jlab_server\\lib\\site-packages (from jupyter-server<2,>=1.8->jupyterlab-server) (6.1)\r\nRequirement already satisfied: Send2Trash in c:\\users\\mikle\\appdata\\roaming\\jupyterlab-desktop\\jlab_server\\lib\\site-packages (from jupyter-server<2,>=1.8->jupyterlab-server) (1.8.0)\r\nRequirement already satisfied: jupyter-core>=4.7.0 in c:\\users\\mikle\\appdata\\roaming\\jupyterlab-desktop\\jlab_server\\lib\\site-packages (from jupyter-server<2,>=1.8->jupyterlab-server) (4.10.0)\r\nRequirement already satisfied: jupyter-client>=6.1.12 in c:\\users\\mikle\\appdata\\roaming\ ...
#
# stderr:  None
#
# mistune
#
# stdout:  b"Requirement already satisfied: mistune in c:\\users\\mikle\\appdata\\roaming\\jupyterlab-desktop\\jlab_server\\lib\\site-packages (0.8.4)\r\nCollecting mistune\r\n  Using cached mistune-2.0.2-py2.py3-none-any.whl (24 kB)\r\nInstalling collected packages: mistune\r\n  Attempting uninstall: mistune\r\n    Found existing installation: mistune 0.8.4\r\n    Uninstalling mistune-0.8.4:\r\n      Successfully uninstalled mistune-0.8.4\r\nERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.\r\nnbconvert 6.5.0 requires mistune<2,>=0.8.1, but you have mistune 2.0.2 which is incompatible.\r\nSuccessfully installed mistune-2.0.2\r\n"
#
# stderr:  None
#
# networkx
#
# stdout:  b'Requirement already satisfied: networkx in c:\\users\\mikle\\appdata\\roaming\\jupyterlab-desktop\\jlab_server\\lib\\site-packages (2.8)\r\nCollecting networkx\r\n  Downloading networkx-2.8.1-py3-none-any.whl (2.0 MB)\r\n     ---------------------------------------- 2.0/2.0 MB 7.1 MB/s eta 0:00:00\r\nInstalling collected packages: networkx\r\n  Attempting uninstall: networkx\r\n    Found existing installation: networkx 2.8\r\n    Uninstalling networkx-2.8:\r\n      Successfully uninstalled networkx-2.8\r\nSuccessfully installed networkx-2.8.1\r\n'
#
# stderr:  None
#
# openpyxl
#
# stdout:  b'Requirement already satisfied: openpyxl in c:\\users\\mikle\\appdata\\roaming\\jupyterlab-desktop\\jlab_server\\lib\\site-packages (3.0.9)\r\nCollecting openpyxl\r\n  Downloading openpyxl-3.0.10-py2.py3-none-any.whl (242 kB)\r\n     -------------------------------------- 242.1/242.1 kB 2.5 MB/s eta 0:00:00\r\nRequirement already satisfied: et-xmlfile in c:\\users\\mikle\\appdata\\roaming\\jupyterlab-desktop\\jlab_server\\lib\\site-packages (from openpyxl) (1.1.0)\r\nInstalling collected packages: openpyxl\r\n  Attempting uninstall: openpyxl\r\n    Found existing installation: openpyxl 3.0.9\r\n    Uninstalling openpyxl-3.0.9:\r\n      Successfully uninstalled openpyxl-3.0.9\r\nSuccessfully installed openpyxl-3.0.10\r\n'
#
# stderr:  None
#
# proto-plus
#
# stdout:  b'Requirement already satisfied: proto-plus in c:\\users\\mikle\\appdata\\roaming\\jupyterlab-desktop\\jlab_server\\lib\\site-packages (1.20.3)\r\nCollecting proto-plus\r\n  Downloading proto_plus-1.20.4-py3-none-any.whl (46 kB)\r\n     ---------------------------------------- 46.4/46.4 kB 1.2 MB/s eta 0:00:00\r\nRequirement already satisfied: protobuf>=3.19.0 in c:\\users\\mikle\\appdata\\roaming\\jupyterlab-desktop\\jlab_server\\lib\\site-packages (from proto-plus) (3.20.1)\r\nInstalling collected packages: proto-plus\r\n  Attempting uninstall: proto-plus\r\n    Found existing installation: proto-plus 1.20.3\r\n    Uninstalling proto-plus-1.20.3:\r\n      Successfully uninstalled proto-plus-1.20.3\r\nSuccessfully installed proto-plus-1.20.4\r\n'
#
# stderr:  None
#
# pywin32
#
# stdout:  b"Requirement already satisfied: pywin32 in c:\\users\\mikle\\appdata\\roaming\\jupyterlab-desktop\\jlab_server\\lib\\site-packages (303)\r\nCollecting pywin32\r\n  Using cached pywin32-304-cp38-cp38-win_amd64.whl (12.3 MB)\r\nInstalling collected packages: pywin32\r\n  Attempting uninstall: pywin32\r\n    Found existing installation: pywin32 303\r\n    Uninstalling pywin32-303:\r\n      Successfully uninstalled pywin32-303\r\n  WARNING: No metadata found in c:\\users\\mikle\\appdata\\roaming\\jupyterlab-desktop\\jlab_server\\lib\\site-packages\r\n  Rolling back uninstall of pywin32\r\n  Moving to c:\\users\\mikle\\appdata\\roaming\\jupyterlab-desktop\\jlab_server\\lib\\site-packages\\__pycache__\\pythoncom.cpython-38.pyc\r\n   from C:\\Users\\mikle\\AppData\\Local\\Temp\\pip-uninstall-2ig0qrap\\pythoncom.cpython-38.pyc\r\n  Moving to c:\\users\\mikle\\appdata\\roaming\\jupyterlab-desktop\\jlab_server\\lib\\site-packages\\adodbapi\r\n   from C:\\Users\\mikle\\AppData\\Roaming\\jupyterlab-desktop\\jlab_server\\Lib\\site-packages\\~dodbapi\r\n  Moving to c:\\users\\mikle\\appdata\\roaming\\jupyterlab-desktop\\jlab_server\\lib\\site-packages\\isapi\r\n   from C:\\Users\\mikle\\AppData\\Roaming\\jupyterlab-desktop\\jlab_server\\Lib\\site-packages\\~sapi\r\n  Moving to c:\\users\\mikle\\appdata\\roaming\\jupyterlab-desktop\\jlab_server\\lib\\site-packages\\pythoncom.py\r\n   from C:\\Users\\mikle\\AppData\\Local\\Temp\\pip-uninstall-oinvo4c6\\pythoncom.py\r\n  Moving to c:\\users\\mikle\\appdata\\roaming\\jupyterlab-desktop\\jlab_server\\lib\\site-packages\\pythonwin\r\n   from C:\\Users\\mikle\\AppData\\Roaming\\jupyterlab-desktop\\jlab_server\\Lib\\site-packages\\~ythonwin\r\n  Moving to c:\\users\\mikle\\appdata\\roaming\\jupyterlab-desktop\\jlab_server\\lib\\site-packages\\pywin32-303-py3.8.egg-info\r\n   from C:\\Users\\mikle\\AppData\\Roaming\\jupyterlab-desktop\\jlab_server\\Lib\\site-packages\\~ywin32-303-py3.8.egg-info\r\n  Moving to c:\\users\\mikle\\appdata\\roaming\\jupyterlab-desktop\\jlab_server\\lib\\site-packages\\win32\\lib\\\r\n   from C:\\Users\\mikle\\AppData\\Roaming\\jupyterlab-desktop\\jlab_server\\Lib\\site-packages\\win32\\~ib\r\n  Moving to c:\\users\\mikle\\appdata\\roaming\\jupyterlab-desktop\\jlab_server\\lib\\site-packages\\win32com\r\n   from C:\\Users\\mikle\\AppData\\Roaming\\jupyterlab-desktop\\jlab_server\\Lib\\site-packages\\~in32com\r\n  Moving to c:\\users\\mikle\\appdata\\roaming\\jupyterlab-desktop\\jlab_server\\lib\\site-packages\\win32comext\r\n   from C:\\Users\\mikle\\AppData\\Roaming\\jupyterlab-desktop\\jlab_server\\Lib\\site-packages\\~in32comext\r\nERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'C:\\\\Users\\\\mikle\\\\AppData\\\\Roaming\\\\jupyterlab-desktop\\\\jlab_server\\\\Lib\\\\site-packages\\\\pywin32_system32\\\\pythoncom38.dll'\r\nConsider using the `--user` option or check the permissions.\r\n\r\n"
#
# stderr:  None
#
# pyzmq
#
# stdout:  b"Requirement already satisfied: pyzmq in c:\\users\\mikle\\appdata\\roaming\\jupyterlab-desktop\\jlab_server\\lib\\site-packages (22.3.0)\r\nCollecting pyzmq\r\n  Downloading pyzmq-23.0.0-cp38-cp38-win_amd64.whl (990 kB)\r\n     -------------------------------------- 990.5/990.5 kB 4.2 MB/s eta 0:00:00\r\nInstalling collected packages: pyzmq\r\n  Attempting uninstall: pyzmq\r\n    Found existing installation: pyzmq 22.3.0\r\n    Uninstalling pyzmq-22.3.0:\r\n      Successfully uninstalled pyzmq-22.3.0\r\nERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'C:\\\\Users\\\\mikle\\\\AppData\\\\Roaming\\\\jupyterlab-desktop\\\\jlab_server\\\\Lib\\\\site-packages\\\\~mq\\\\backend\\\\cython\\\\constants.cp38-win_amd64.pyd'\r\nConsider using the `--user` option or check the permissions.\r\n\r\n"
#
# stderr:  None
#
# scipy
#
# stdout:  b'Requirement already satisfied: scipy in c:\\users\\mikle\\appdata\\roaming\\jupyterlab-desktop\\jlab_server\\lib\\site-packages (1.8.0)\r\nCollecting scipy\r\n  Downloading scipy-1.8.1-cp38-cp38-win_amd64.whl (36.9 MB)\r\n     --------------------------------------- 36.9/36.9 MB 22.6 MB/s eta 0:00:00\r\nRequirement already satisfied: numpy<1.25.0,>=1.17.3 in c:\\users\\mikle\\appdata\\roaming\\jupyterlab-desktop\\jlab_server\\lib\\site-packages (from scipy) (1.22.3)\r\nInstalling collected packages: scipy\r\n  Attempting uninstall: scipy\r\n    Found existing installation: scipy 1.8.0\r\n    Uninstalling scipy-1.8.0:\r\n      Successfully uninstalled scipy-1.8.0\r\nSuccessfully installed scipy-1.8.1\r\n'
#
# stderr:  None
#
# setuptools
#
# stdout:  b'Requirement already satisfied: setuptools in c:\\users\\mikle\\appdata\\roaming\\jupyterlab-desktop\\jlab_server\\lib\\site-packages (62.3.1)\r\nCollecting setuptools\r\n  Downloading setuptools-62.3.2-py3-none-any.whl (1.2 MB)\r\n     ---------------------------------------- 1.2/1.2 MB 4.1 MB/s eta 0:00:00\r\nInstalling collected packages: setuptools\r\n  Attempting uninstall: setuptools\r\n    Found existing installation: setuptools 62.3.1\r\n    Uninstalling setuptools-62.3.1:\r\n      Successfully uninstalled setuptools-62.3.1\r\nSuccessfully installed setuptools-62.3.2\r\n'
#
# stderr:  None
#
# Done

# %%
outputs
# Out:
# [('certifi',
#   b"Requirement already satisfied: certifi in c:\\users\\mikle\\appdata\\roaming\\jupyterlab-desktop\\jlab_server\\lib\\site-packages (2021.10.8)\r\nCollecting certifi\r\n  Downloading certifi-2022.5.18.1-py3-none-any.whl (155 kB)\r\n     -------------------------------------- 155.2/155.2 kB 1.9 MB/s eta 0:00:00\r\nInstalling collected packages: certifi\r\n  Attempting uninstall: certifi\r\n    Found existing installation: certifi 2021.10.8\r\n    Uninstalling certifi-2021.10.8:\r\n      Successfully uninstalled certifi-2021.10.8\r\nERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.\r\npyppeteer 1.0.2 requires pyee<9.0.0,>=8.1.0, but you have pyee 9.0.4 which is incompatible.\r\nhttpx 0.22.0 requires httpcore<0.15.0,>=0.14.5, but you have httpcore 0.15.0 which is incompatible.\r\nhttpx 0.22.0 requires rfc3986[idna2008]<2,>=1.3, but you have rfc3986 2.0.0 which is incompatible.\r\nSuccessfully installed certifi-2022.5.18.1\r\n",
#   None),
#  ('google-analytics-admin',
#   b'Requirement already satisfied: google-analytics-admin in c:\\users\\mikle\\appdata\\roaming\\jupyterlab-desktop\\jlab_server\\lib\\site-packages (0.8.0)\r\nCollecting google-analytics-admin\r\n  Downloading google_analytics_admin-0.8.1-py2.py3-none-any.whl (98 kB)\r\n     ---------------------------------------- 99.0/99.0 kB 1.4 MB/s eta 0:00:00\r\nRequirement already satisfied: proto-plus>=1.15.0 in c:\\users\\mikle\\appdata\\roaming\\jupyterlab-desktop\\jlab_server\\lib\\site-packages (from google-analytics-admin) (1.20.3)\r\nRequirement already satisfied: google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5 in c:\\users\\mikle\\appdata\\roaming\\jupyterlab-desktop\\jlab_server\\lib\\site-packages (from google-analytics-admin) (2.7.3)\r\nRequirement already satisfied: google-auth<3.0dev,>=1.25.0 in c:\\users\\mikle\\appdata\\roaming\\jupyterlab-desktop\\jlab_server\\lib\\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-analytics-admin) (2.6.6)\r\nRequirement already satisfied: protobuf>=3.12.0 in c:\\users\\mikle\\appdata\\roaming\\jupyterlab-desktop\\jlab_server\\lib\\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-analytics-admin) (3.20.1)\r\nRequirement already satisfied: requests<3.0.0dev,>=2.18.0 in c:\\users\\mikle\\appdata\\roaming\\jupyterlab-desktop\\jlab_server\\lib\\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-analytics-admin) (2.27.1)\r\nRequirement already satisfied: googleapis-common-protos<2.0dev,>=1.52.0 in c:\\users\\mikle\\appdata\\roaming\\jupyterlab-desktop\\jlab_server\\lib\\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-analytics-admin) (1.56.1)\r\nRequirement already satisfied: grpcio<2.0dev,>=1.33.2 in c:\\users\\mikle\\appdata\\roaming\\jupyterlab-desktop\\jlab_server\\lib\\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-analytics-admin) (1.46.1)\r\nRequirement already satisfied: grpcio-status<2.0dev,>=1.33.2 in c:\\users\\mikle\\appdata\\roaming\\jupyterlab-desktop\\jlab_server\\lib\\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-analytics-admin) (1.46.1)\r\nRequirement already satisfied: rsa<5,>=3.1.4 in c:\\users\\mikle\\appdata\\roaming\\jupyterlab-desktop\\jlab_server\\lib\\site-packages (from google-auth<3.0dev,>=1.25.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-analytics-admin) (4.8)\r\nRequirement already satisfied: cachetools<6.0,>=2.0.0 in c:\\users\\mikle\\appdata\\roaming\\jupyterlab-desktop\\jlab_server\\lib\\site-packages (from google-auth<3.0dev,>=1.25.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-analytics-admin) (5.1.0)\r\nRequirement already satisfied: pyasn1-modules>=0.2.1 in c:\\users\\mikle\\appdata\\roaming\\jupyterlab-desktop\\jlab_server\\lib\\site-packages (from google-auth<3.0dev,>=1.25.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-analytics-admin) (0.2.8)\r\nRequirement already satisfied: six>=1.9.0 in c:\\users\\mikle\\appdata\\roaming\\jupyterlab-desktop\\jlab_server\\lib\\site-packages (from google-auth<3.0dev,>=1.25.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-analytics-admin) (1.16.0)\r\nRequirement already satisfied: certifi>=2017.4.17 in c:\\users\\mikle\\appdata\\roaming\\jupyterlab-desktop\\jlab_server\\lib\\site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-analytics-admin) (2022.5.18.1)\r\nRequirement already satisfied: idna<4,>=2.5 in c:\\users\\mikle\\appdata\\roaming\\jupyterlab-desktop\\jlab_server\\lib\\site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0, ...
#   None),
#  ('google-api-core',
#   b'Requirement already satisfied: google-api-core in c:\\users\\mikle\\appdata\\roaming\\jupyterlab-desktop\\jlab_server\\lib\\site-packages (2.7.3)\r\nCollecting google-api-core\r\n  Downloading google_api_core-2.8.0-py3-none-any.whl (114 kB)\r\n     -------------------------------------- 114.7/114.7 kB 1.7 MB/s eta 0:00:00\r\nRequirement already satisfied: requests<3.0.0dev,>=2.18.0 in c:\\users\\mikle\\appdata\\roaming\\jupyterlab-desktop\\jlab_server\\lib\\site-packages (from google-api-core) (2.27.1)\r\nRequirement already satisfied: protobuf>=3.12.0 in c:\\users\\mikle\\appdata\\roaming\\jupyterlab-desktop\\jlab_server\\lib\\site-packages (from google-api-core) (3.20.1)\r\nRequirement already satisfied: googleapis-common-protos<2.0dev,>=1.52.0 in c:\\users\\mikle\\appdata\\roaming\\jupyterlab-desktop\\jlab_server\\lib\\site-packages (from google-api-core) (1.56.1)\r\nRequirement already satisfied: google-auth<3.0dev,>=1.25.0 in c:\\users\\mikle\\appdata\\roaming\\jupyterlab-desktop\\jlab_server\\lib\\site-packages (from google-api-core) (2.6.6)\r\nRequirement already satisfied: six>=1.9.0 in c:\\users\\mikle\\appdata\\roaming\\jupyterlab-desktop\\jlab_server\\lib\\site-packages (from google-auth<3.0dev,>=1.25.0->google-api-core) (1.16.0)\r\nRequirement already satisfied: pyasn1-modules>=0.2.1 in c:\\users\\mikle\\appdata\\roaming\\jupyterlab-desktop\\jlab_server\\lib\\site-packages (from google-auth<3.0dev,>=1.25.0->google-api-core) (0.2.8)\r\nRequirement already satisfied: cachetools<6.0,>=2.0.0 in c:\\users\\mikle\\appdata\\roaming\\jupyterlab-desktop\\jlab_server\\lib\\site-packages (from google-auth<3.0dev,>=1.25.0->google-api-core) (5.1.0)\r\nRequirement already satisfied: rsa<5,>=3.1.4 in c:\\users\\mikle\\appdata\\roaming\\jupyterlab-desktop\\jlab_server\\lib\\site-packages (from google-auth<3.0dev,>=1.25.0->google-api-core) (4.8)\r\nRequirement already satisfied: charset-normalizer~=2.0.0 in c:\\users\\mikle\\appdata\\roaming\\jupyterlab-desktop\\jlab_server\\lib\\site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core) (2.0.12)\r\nRequirement already satisfied: urllib3<1.27,>=1.21.1 in c:\\users\\mikle\\appdata\\roaming\\jupyterlab-desktop\\jlab_server\\lib\\site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core) (1.26.9)\r\nRequirement already satisfied: certifi>=2017.4.17 in c:\\users\\mikle\\appdata\\roaming\\jupyterlab-desktop\\jlab_server\\lib\\site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core) (2022.5.18.1)\r\nRequirement already satisfied: idna<4,>=2.5 in c:\\users\\mikle\\appdata\\roaming\\jupyterlab-desktop\\jlab_server\\lib\\site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core) (3.3)\r\nRequirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\\users\\mikle\\appdata\\roaming\\jupyterlab-desktop\\jlab_server\\lib\\site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0dev,>=1.25.0->google-api-core) (0.4.8)\r\nInstalling collected packages: google-api-core\r\n  Attempting uninstall: google-api-core\r\n    Found existing installation: google-api-core 2.7.3\r\n    Uninstalling google-api-core-2.7.3:\r\n      Successfully uninstalled google-api-core-2.7.3\r\nSuccessfully installed google-api-core-2.8.0\r\n',
#   None),
#  ('h11',
#   b"Requirement already satisfied: h11 in c:\\users\\mikle\\appdata\\roaming\\jupyterlab-desktop\\jlab_server\\lib\\site-packages (0.12.0)\r\nCollecting h11\r\n  Using cached h11-0.13.0-py3-none-any.whl (58 kB)\r\nInstalling collected packages: h11\r\n  Attempting uninstall: h11\r\n    Found existing installation: h11 0.12.0\r\n    Uninstalling h11-0.12.0:\r\n      Successfully uninstalled h11-0.12.0\r\nERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.\r\nhttpcore 0.15.0 requires h11<0.13,>=0.11, but you have h11 0.13.0 which is incompatible.\r\nSuccessfully installed h11-0.13.0\r\n",
#   None),
#  ('Jinja2',
#   b"Requirement already satisfied: Jinja2 in c:\\users\\mikle\\appdata\\roaming\\jupyterlab-desktop\\jlab_server\\lib\\site-packages (3.0.3)\r\nCollecting Jinja2\r\n  Using cached Jinja2-3.1.2-py3-none-any.whl (133 kB)\r\nRequirement already satisfied: MarkupSafe>=2.0 in c:\\users\\mikle\\appdata\\roaming\\jupyterlab-desktop\\jlab_server\\lib\\site-packages (from Jinja2) (2.1.1)\r\nInstalling collected packages: Jinja2\r\n  Attempting uninstall: Jinja2\r\n    Found existing installation: Jinja2 3.0.3\r\n    Uninstalling Jinja2-3.0.3:\r\n      Successfully uninstalled Jinja2-3.0.3\r\nERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.\r\nnbdev 1.2.8 requires Jinja2<3.1.0, but you have jinja2 3.1.2 which is incompatible.\r\nSuccessfully installed Jinja2-3.1.2\r\n",
#   None),
#  ('jupyterlab-server',
#   b'Requirement already satisfied: jupyterlab-server in c:\\users\\mikle\\appdata\\roaming\\jupyterlab-desktop\\jlab_server\\lib\\site-packages (2.13.0)\r\nCollecting jupyterlab-server\r\n  Downloading jupyterlab_server-2.14.0-py3-none-any.whl (54 kB)\r\n     -------------------------------------- 54.3/54.3 kB 957.4 kB/s eta 0:00:00\r\nRequirement already satisfied: packaging in c:\\users\\mikle\\appdata\\roaming\\jupyterlab-desktop\\jlab_server\\lib\\site-packages (from jupyterlab-server) (21.3)\r\nRequirement already satisfied: jinja2>=3.0.3 in c:\\users\\mikle\\appdata\\roaming\\jupyterlab-desktop\\jlab_server\\lib\\site-packages (from jupyterlab-server) (3.1.2)\r\nRequirement already satisfied: importlib-metadata>=3.6 in c:\\users\\mikle\\appdata\\roaming\\jupyterlab-desktop\\jlab_server\\lib\\site-packages (from jupyterlab-server) (4.11.3)\r\nRequirement already satisfied: jsonschema>=3.0.1 in c:\\users\\mikle\\appdata\\roaming\\jupyterlab-desktop\\jlab_server\\lib\\site-packages (from jupyterlab-server) (4.5.1)\r\nRequirement already satisfied: json5 in c:\\users\\mikle\\appdata\\roaming\\jupyterlab-desktop\\jlab_server\\lib\\site-packages (from jupyterlab-server) (0.9.8)\r\nRequirement already satisfied: babel in c:\\users\\mikle\\appdata\\roaming\\jupyterlab-desktop\\jlab_server\\lib\\site-packages (from jupyterlab-server) (2.10.1)\r\nRequirement already satisfied: jupyter-server<2,>=1.8 in c:\\users\\mikle\\appdata\\roaming\\jupyterlab-desktop\\jlab_server\\lib\\site-packages (from jupyterlab-server) (1.17.0)\r\nRequirement already satisfied: requests in c:\\users\\mikle\\appdata\\roaming\\jupyterlab-desktop\\jlab_server\\lib\\site-packages (from jupyterlab-server) (2.27.1)\r\nRequirement already satisfied: zipp>=0.5 in c:\\users\\mikle\\appdata\\roaming\\jupyterlab-desktop\\jlab_server\\lib\\site-packages (from importlib-metadata>=3.6->jupyterlab-server) (3.8.0)\r\nRequirement already satisfied: MarkupSafe>=2.0 in c:\\users\\mikle\\appdata\\roaming\\jupyterlab-desktop\\jlab_server\\lib\\site-packages (from jinja2>=3.0.3->jupyterlab-server) (2.1.1)\r\nRequirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\\users\\mikle\\appdata\\roaming\\jupyterlab-desktop\\jlab_server\\lib\\site-packages (from jsonschema>=3.0.1->jupyterlab-server) (0.18.1)\r\nRequirement already satisfied: attrs>=17.4.0 in c:\\users\\mikle\\appdata\\roaming\\jupyterlab-desktop\\jlab_server\\lib\\site-packages (from jsonschema>=3.0.1->jupyterlab-server) (21.4.0)\r\nRequirement already satisfied: importlib-resources>=1.4.0 in c:\\users\\mikle\\appdata\\roaming\\jupyterlab-desktop\\jlab_server\\lib\\site-packages (from jsonschema>=3.0.1->jupyterlab-server) (5.7.1)\r\nRequirement already satisfied: argon2-cffi in c:\\users\\mikle\\appdata\\roaming\\jupyterlab-desktop\\jlab_server\\lib\\site-packages (from jupyter-server<2,>=1.8->jupyterlab-server) (21.3.0)\r\nRequirement already satisfied: websocket-client in c:\\users\\mikle\\appdata\\roaming\\jupyterlab-desktop\\jlab_server\\lib\\site-packages (from jupyter-server<2,>=1.8->jupyterlab-server) (1.3.2)\r\nRequirement already satisfied: nbconvert>=6.4.4 in c:\\users\\mikle\\appdata\\roaming\\jupyterlab-desktop\\jlab_server\\lib\\site-packages (from jupyter-server<2,>=1.8->jupyterlab-server) (6.5.0)\r\nRequirement already satisfied: tornado>=6.1.0 in c:\\users\\mikle\\appdata\\roaming\\jupyterlab-desktop\\jlab_server\\lib\\site-packages (from jupyter-server<2,>=1.8->jupyterlab-server) (6.1)\r\nRequirement already satisfied: Send2Trash in c:\\users\\mikle\\appdata\\roaming\\jupyterlab-desktop\\jlab_server\\lib\\site-packages (from jupyter-server<2,>=1.8->jupyterlab-server) (1.8.0)\r\nRequirement already satisfied: jupyter-core>=4.7.0 in c:\\users\\mikle\\appdata\\roaming\\jupyterlab-desktop\\jlab_server\\lib\\site-packages (from jupyter-server<2,>=1.8->jupyterlab-server) (4.10.0)\r\nRequirement already satisfied: jupyter-client>=6.1.12 in c:\\users\\mikle\\appdata\\roaming\\jupyte ...
#   None),
#  ('mistune',
#   b"Requirement already satisfied: mistune in c:\\users\\mikle\\appdata\\roaming\\jupyterlab-desktop\\jlab_server\\lib\\site-packages (0.8.4)\r\nCollecting mistune\r\n  Using cached mistune-2.0.2-py2.py3-none-any.whl (24 kB)\r\nInstalling collected packages: mistune\r\n  Attempting uninstall: mistune\r\n    Found existing installation: mistune 0.8.4\r\n    Uninstalling mistune-0.8.4:\r\n      Successfully uninstalled mistune-0.8.4\r\nERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.\r\nnbconvert 6.5.0 requires mistune<2,>=0.8.1, but you have mistune 2.0.2 which is incompatible.\r\nSuccessfully installed mistune-2.0.2\r\n",
#   None),
#  ('networkx',
#   b'Requirement already satisfied: networkx in c:\\users\\mikle\\appdata\\roaming\\jupyterlab-desktop\\jlab_server\\lib\\site-packages (2.8)\r\nCollecting networkx\r\n  Downloading networkx-2.8.1-py3-none-any.whl (2.0 MB)\r\n     ---------------------------------------- 2.0/2.0 MB 7.1 MB/s eta 0:00:00\r\nInstalling collected packages: networkx\r\n  Attempting uninstall: networkx\r\n    Found existing installation: networkx 2.8\r\n    Uninstalling networkx-2.8:\r\n      Successfully uninstalled networkx-2.8\r\nSuccessfully installed networkx-2.8.1\r\n',
#   None),
#  ('openpyxl',
#   b'Requirement already satisfied: openpyxl in c:\\users\\mikle\\appdata\\roaming\\jupyterlab-desktop\\jlab_server\\lib\\site-packages (3.0.9)\r\nCollecting openpyxl\r\n  Downloading openpyxl-3.0.10-py2.py3-none-any.whl (242 kB)\r\n     -------------------------------------- 242.1/242.1 kB 2.5 MB/s eta 0:00:00\r\nRequirement already satisfied: et-xmlfile in c:\\users\\mikle\\appdata\\roaming\\jupyterlab-desktop\\jlab_server\\lib\\site-packages (from openpyxl) (1.1.0)\r\nInstalling collected packages: openpyxl\r\n  Attempting uninstall: openpyxl\r\n    Found existing installation: openpyxl 3.0.9\r\n    Uninstalling openpyxl-3.0.9:\r\n      Successfully uninstalled openpyxl-3.0.9\r\nSuccessfully installed openpyxl-3.0.10\r\n',
#   None),
#  ('proto-plus',
#   b'Requirement already satisfied: proto-plus in c:\\users\\mikle\\appdata\\roaming\\jupyterlab-desktop\\jlab_server\\lib\\site-packages (1.20.3)\r\nCollecting proto-plus\r\n  Downloading proto_plus-1.20.4-py3-none-any.whl (46 kB)\r\n     ---------------------------------------- 46.4/46.4 kB 1.2 MB/s eta 0:00:00\r\nRequirement already satisfied: protobuf>=3.19.0 in c:\\users\\mikle\\appdata\\roaming\\jupyterlab-desktop\\jlab_server\\lib\\site-packages (from proto-plus) (3.20.1)\r\nInstalling collected packages: proto-plus\r\n  Attempting uninstall: proto-plus\r\n    Found existing installation: proto-plus 1.20.3\r\n    Uninstalling proto-plus-1.20.3:\r\n      Successfully uninstalled proto-plus-1.20.3\r\nSuccessfully installed proto-plus-1.20.4\r\n',
#   None),
#  ('pywin32',
#   b"Requirement already satisfied: pywin32 in c:\\users\\mikle\\appdata\\roaming\\jupyterlab-desktop\\jlab_server\\lib\\site-packages (303)\r\nCollecting pywin32\r\n  Using cached pywin32-304-cp38-cp38-win_amd64.whl (12.3 MB)\r\nInstalling collected packages: pywin32\r\n  Attempting uninstall: pywin32\r\n    Found existing installation: pywin32 303\r\n    Uninstalling pywin32-303:\r\n      Successfully uninstalled pywin32-303\r\n  WARNING: No metadata found in c:\\users\\mikle\\appdata\\roaming\\jupyterlab-desktop\\jlab_server\\lib\\site-packages\r\n  Rolling back uninstall of pywin32\r\n  Moving to c:\\users\\mikle\\appdata\\roaming\\jupyterlab-desktop\\jlab_server\\lib\\site-packages\\__pycache__\\pythoncom.cpython-38.pyc\r\n   from C:\\Users\\mikle\\AppData\\Local\\Temp\\pip-uninstall-2ig0qrap\\pythoncom.cpython-38.pyc\r\n  Moving to c:\\users\\mikle\\appdata\\roaming\\jupyterlab-desktop\\jlab_server\\lib\\site-packages\\adodbapi\r\n   from C:\\Users\\mikle\\AppData\\Roaming\\jupyterlab-desktop\\jlab_server\\Lib\\site-packages\\~dodbapi\r\n  Moving to c:\\users\\mikle\\appdata\\roaming\\jupyterlab-desktop\\jlab_server\\lib\\site-packages\\isapi\r\n   from C:\\Users\\mikle\\AppData\\Roaming\\jupyterlab-desktop\\jlab_server\\Lib\\site-packages\\~sapi\r\n  Moving to c:\\users\\mikle\\appdata\\roaming\\jupyterlab-desktop\\jlab_server\\lib\\site-packages\\pythoncom.py\r\n   from C:\\Users\\mikle\\AppData\\Local\\Temp\\pip-uninstall-oinvo4c6\\pythoncom.py\r\n  Moving to c:\\users\\mikle\\appdata\\roaming\\jupyterlab-desktop\\jlab_server\\lib\\site-packages\\pythonwin\r\n   from C:\\Users\\mikle\\AppData\\Roaming\\jupyterlab-desktop\\jlab_server\\Lib\\site-packages\\~ythonwin\r\n  Moving to c:\\users\\mikle\\appdata\\roaming\\jupyterlab-desktop\\jlab_server\\lib\\site-packages\\pywin32-303-py3.8.egg-info\r\n   from C:\\Users\\mikle\\AppData\\Roaming\\jupyterlab-desktop\\jlab_server\\Lib\\site-packages\\~ywin32-303-py3.8.egg-info\r\n  Moving to c:\\users\\mikle\\appdata\\roaming\\jupyterlab-desktop\\jlab_server\\lib\\site-packages\\win32\\lib\\\r\n   from C:\\Users\\mikle\\AppData\\Roaming\\jupyterlab-desktop\\jlab_server\\Lib\\site-packages\\win32\\~ib\r\n  Moving to c:\\users\\mikle\\appdata\\roaming\\jupyterlab-desktop\\jlab_server\\lib\\site-packages\\win32com\r\n   from C:\\Users\\mikle\\AppData\\Roaming\\jupyterlab-desktop\\jlab_server\\Lib\\site-packages\\~in32com\r\n  Moving to c:\\users\\mikle\\appdata\\roaming\\jupyterlab-desktop\\jlab_server\\lib\\site-packages\\win32comext\r\n   from C:\\Users\\mikle\\AppData\\Roaming\\jupyterlab-desktop\\jlab_server\\Lib\\site-packages\\~in32comext\r\nERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'C:\\\\Users\\\\mikle\\\\AppData\\\\Roaming\\\\jupyterlab-desktop\\\\jlab_server\\\\Lib\\\\site-packages\\\\pywin32_system32\\\\pythoncom38.dll'\r\nConsider using the `--user` option or check the permissions.\r\n\r\n",
#   None),
#  ('pyzmq',
#   b"Requirement already satisfied: pyzmq in c:\\users\\mikle\\appdata\\roaming\\jupyterlab-desktop\\jlab_server\\lib\\site-packages (22.3.0)\r\nCollecting pyzmq\r\n  Downloading pyzmq-23.0.0-cp38-cp38-win_amd64.whl (990 kB)\r\n     -------------------------------------- 990.5/990.5 kB 4.2 MB/s eta 0:00:00\r\nInstalling collected packages: pyzmq\r\n  Attempting uninstall: pyzmq\r\n    Found existing installation: pyzmq 22.3.0\r\n    Uninstalling pyzmq-22.3.0:\r\n      Successfully uninstalled pyzmq-22.3.0\r\nERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'C:\\\\Users\\\\mikle\\\\AppData\\\\Roaming\\\\jupyterlab-desktop\\\\jlab_server\\\\Lib\\\\site-packages\\\\~mq\\\\backend\\\\cython\\\\constants.cp38-win_amd64.pyd'\r\nConsider using the `--user` option or check the permissions.\r\n\r\n",
#   None),
#  ('scipy',
#   b'Requirement already satisfied: scipy in c:\\users\\mikle\\appdata\\roaming\\jupyterlab-desktop\\jlab_server\\lib\\site-packages (1.8.0)\r\nCollecting scipy\r\n  Downloading scipy-1.8.1-cp38-cp38-win_amd64.whl (36.9 MB)\r\n     --------------------------------------- 36.9/36.9 MB 22.6 MB/s eta 0:00:00\r\nRequirement already satisfied: numpy<1.25.0,>=1.17.3 in c:\\users\\mikle\\appdata\\roaming\\jupyterlab-desktop\\jlab_server\\lib\\site-packages (from scipy) (1.22.3)\r\nInstalling collected packages: scipy\r\n  Attempting uninstall: scipy\r\n    Found existing installation: scipy 1.8.0\r\n    Uninstalling scipy-1.8.0:\r\n      Successfully uninstalled scipy-1.8.0\r\nSuccessfully installed scipy-1.8.1\r\n',
#   None),
#  ('setuptools',
#   b'Requirement already satisfied: setuptools in c:\\users\\mikle\\appdata\\roaming\\jupyterlab-desktop\\jlab_server\\lib\\site-packages (62.3.1)\r\nCollecting setuptools\r\n  Downloading setuptools-62.3.2-py3-none-any.whl (1.2 MB)\r\n     ---------------------------------------- 1.2/1.2 MB 4.1 MB/s eta 0:00:00\r\nInstalling collected packages: setuptools\r\n  Attempting uninstall: setuptools\r\n    Found existing installation: setuptools 62.3.1\r\n    Uninstalling setuptools-62.3.1:\r\n      Successfully uninstalled setuptools-62.3.1\r\nSuccessfully installed setuptools-62.3.2\r\n',
#   None)]

# %%
# hide
# Take a look at held-back components.

# !pip list -o
# Out:
# Package Version Latest Type
# ------- ------- ------ -----
# pywin32 303     304    wheel

# %% [markdown]
# # Reverting a Version
#
# Sometimes things get messed up. The messages during the upgrade usually clue you in, but running the upgrades twice can override the held-back upgrades. If you accidentally overwrite a particular version dependency, you can find it in your requirements.txt and deliberately go back to the required version with a command like this:

# %%
# hide

# !pip install -U mistune==0.8.4
# Out:
# Collecting mistune==0.8.4
#   Using cached mistune-0.8.4-py2.py3-none-any.whl (16 kB)
# Installing collected packages: mistune
#   Attempting uninstall: mistune
#     Found existing installation: mistune 2.0.2
#     Uninstalling mistune-2.0.2:
#       Successfully uninstalled mistune-2.0.2
# Successfully installed mistune-0.8.4

# %%
# It's always a good idea to restart your kernel after this.
# Better yet, quit and re-load Jupyter. It might have been updated!

# %%
from platform import python_version

# %%
python_version()
# Out:
# '3.8.13'
